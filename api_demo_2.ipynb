# %%
# Import required libraries for API requests and YAML config parsing
import requests
import json
import yaml
from pathlib import Path
# Import the main extractor class from the installed package
from monday_board_extractor import MondayColumnExtractor

# %%
import json
import logging
import requests
from typing import Any


import requests
import json
import logging

class MondayColumnUpdater:
    def __init__(self, api_key: str):
        self.url = "https://api.monday.com/v2"
        self.headers = {
            "Authorization": api_key,
            "Content-Type": "application/json"
        }

    def update_column_value(
        self,
        board_id: int,
        item_id: int,
        column_id: str,
        value: str
        ) -> dict:
            # Double encoding required by Monday.com GraphQL spec
        wrapped_value = json.dumps(json.dumps({"text": value}))

        mutation = f'''
            mutation {{
                change_column_value(
                    board_id: {board_id},
                    item_id: {item_id},
                    column_id: "{column_id}",
                    value: {wrapped_value}
                ) {{
                id
                }}
            }}
        '''

        payload = {"query": mutation}
        print("=== GraphQL Mutation Payload ===")
        print(json.dumps(payload, indent=2))

        try:
            response = requests.post(
                self.url,
                json=payload,
                headers=self.headers
            )
            response.raise_for_status()
            return response.json()
        except requests.RequestException as e:
            logging.error(f"Update request failed: {e}")
            raise
        except Exception as e:
            logging.error(f"Unexpected error during update: {e}")
            raise

# %%
# Automatically look for 'monday_config.yaml' in the current working directory (project root)
config_path = Path.cwd() / "monday_config.yaml"
if not config_path.exists():
    raise FileNotFoundError(f"Config file not found at {config_path}. Please ensure 'monday_config.yaml' is in the project root.")

with config_path.open("r") as f:
    config = yaml.safe_load(f)

api_key = config["monday"]["api_key"]

# %%
board_ids = [8033166260]

extractor = MondayColumnExtractor(api_key, board_ids)
results = extractor.extract()

# To access one dataframe by board name:
for board_data in results:
    print(board_data.name)

board_data.data
# Out:
# PD Program
#          pm_Mjj4IJZX                                financials_Mjj4L6Yo  \
# 0
# 1     Martin Blancas  Total Project Budget: $12,000,000.00\nDesign B...
# 2        Nancy Lopez  Total Project Budget: $8,081,821.00\nDesign Bu...
# 3        Jesus Palma  Total Project Budget: $7,105,706\nDesign Budge...
# 4       Jorge Chacon  Total Project Budget: $7,430,635.47\nDesign Bu...
# 5    Daniel Carrillo  Total Project Budget: $23,616,000\nDesign Budg...
# 6  Nicholas Gonzales  Total Project Budget: $\nDesign Budget: $\nCon...
#
#   dor_Mjj4yLIK active_task_Mjj4FJQL  \
# 0                          Planning
# 1          MNK               Design
# 2       DEKKER               Design
# 3   CDA/DEKKER            Predesign
# 4          TBD            Predesign
# 5          ASA               Design
# 6       DEKKER             Planning
#
#                                     comment_Mjj4ErAr contractor_Mjj47NUD  \
# 0
# 1  Plans sent to PD, EPWater, Facilities, IT, and...                 TBD
# 2                    30% CDR scheduled for 8/27/2025                 TBD
# 3  Restrooms to be completed by 10/20/2025.  Docu...               VELIZ
# 4  In negotiations with MNK on proposal.  Rate fo...                 TBD
# 5  60% plans due 9/26/2025.  Last OPC provided wa...                 TBD
# 6  Reduce sq ft reduction by 30,000.  Pending upd...                 TBD
#
#   date_mkv8epda date_mkv89r9t date_mkv8xss3 project_timeline  ...  \
# 0                                                             ...
# 1                                                             ...
# 2                                                             ...
# 3                                                             ...
# 4                                                             ...
# 5                                                             ...
# 6                                                             ...
#
#   formula_mktys6gm project_duration project_task_completion_date  \
# 0
# 1
# 2
# 3
# 4
# 5
# 6
#
#   date_mktynmfm formula_mktyrxna subitems_Mjj4Ab1e project_owner  \
# 0                                             None
# 1                                             None
# 2                                             None
# 3                                             None
# 4                                             None
# 5                                             None
# 6                                             None
#
#   project_status active_task_Mjj45kec project_budget
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# 5           None
# 6           None
#
# [7 rows x 21 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
updater = MondayColumnUpdater(api_key=api_key)

new_financial_text = (
    "Total Project Budget: $12,000,000.00\n"
    "Design Budget: $900,000.00\n"
    "Construction Budget: $9,000,000.00"
)

response = updater.update_column_value(
    board_id=8033166260,
    item_id=8034118992,
    column_id="financials_Mjj4L6Yo",
    value=new_financial_text
)

print(response)
# Out:
# === GraphQL Mutation Payload ===
# {
#   "query": "\n        mutation {\n        change_column_value(\n        board_id: 8033166260,\n        item_id: 8034118992,\n        column_id: \"financials_Mjj4L6Yo\",\n        value: \"{\\\"text\\\": \\\"Total Project Budget: $12,000,000.00\\\\nDesign Budget: $900,000.00\\\\nConstruction Budget: $9,000,000.00\\\"}\"\n      ) {\n        id\n      }\n    }\n    "
# }
# {'data': {'change_column_value': {'id': '8034118992'}}, 'extensions': {'request_id': '17dc3d40-7ceb-9548-b7fd-532be4e34c2f'}}

# %%
extractor._fetch_data()
# Out:
# {'data': {'boards': [{'name': 'PD Program',
#     'items_page': {'items': [{'id': '9842734550',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': ''},
#         {'id': 'financials_Mjj4L6Yo', 'text': ''},
#         {'id': 'dor_Mjj4yLIK', 'text': ''},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Planning'},
#         {'id': 'comment_Mjj4ErAr', 'text': ''},
#         {'id': 'contractor_Mjj47NUD', 'text': ''},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]},
#       {'id': '8034118992',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': 'Martin Blancas'},
#         {'id': 'financials_Mjj4L6Yo',
#          'text': 'Total Project Budget: $12,000,000.00\nDesign Budget: $900,000.00\nConstruction Budget: $9,000,000.00'},
#         {'id': 'dor_Mjj4yLIK', 'text': 'MNK'},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Design'},
#         {'id': 'comment_Mjj4ErAr', 'text': '30% plans due on 4/18'},
#         {'id': 'contractor_Mjj47NUD', 'text': 'TBD'},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]},
#       {'id': '8034119049',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': 'Nancy Lopez'},
#         {'id': 'financials_Mjj4L6Yo',
#          'text': 'Total Project Budget: $8,081,821.00\nDesign Budget: $552,189.28\nConstructiion Budget $:6,179,516.45'},
#         {'id': 'dor_Mjj4yLIK', 'text': 'DEKKER'},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Design'},
#         {'id': 'comment_Mjj4ErAr', 'text': 'May 19 concept phase'},
#         {'id': 'contractor_Mjj47NUD', 'text': 'TBD'},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]},
#       {'id': '8034119098',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': 'Jesus Palma'},
#         {'id': 'financials_Mjj4L6Yo',
#          'text': 'Total Project Budget: $7,105,706\nDesign Budget: $739,852.36\nConstructiion Budget $:4,932,349.07'},
#         {'id': 'dor_Mjj4yLIK', 'text': 'CDA/DEKKER'},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Predesign'},
#         {'id': 'comment_Mjj4ErAr',
#          'text': 'Restrooms - Veliz $337,000 Proposal vs. OPC $304,000 - RS Means breakdown due on 4/18\nRFQ - to post on 04/18 \nRFQ - $'},
#         {'id': 'contractor_Mjj47NUD', 'text': 'VELIZ'},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]},
#       {'id': '8034119196',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': 'Jorge Chacon'},
#         {'id': 'financials_Mjj4L6Yo',
#          'text': 'Total Project Budget: $7,430,635.47\nDesign Budget: $1,225,838.65\nConstructiion Budget $:5,107,661.05'},
#         {'id': 'dor_Mjj4yLIK', 'text': 'TBD'},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Predesign'},
#         {'id': 'comment_Mjj4ErAr',
#          'text': 'RFQ - to be posted; Phasing need to look at Parking for staging area'},
#         {'id': 'contractor_Mjj47NUD', 'text': 'TBD'},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]},
#       {'id': '8034119147',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': 'Daniel Carrillo'},
#         {'id': 'financials_Mjj4L6Yo',
#          'text': 'Total Project Budget: $23,616,000\nDesign Budget: $1,968,000\nConstructiion Budget $:13,454,738'},
#         {'id': 'dor_Mjj4yLIK', 'text': 'ASA'},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Design'},
#         {'id': 'comment_Mjj4ErAr', 'text': '30% plans due 5/12'},
#         {'id': 'contractor_Mjj47NUD', 'text': 'TBD'},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]},
#       {'id': '8034209069',
#        'column_values': [{'id': 'pm_Mjj4IJZX', 'text': 'Nicholas Gonzales'},
#         {'id': 'financials_Mjj4L6Yo',
#          'text': 'Total Project Budget: $\nDesign Budget: $\nConstructiion Budget $:'},
#         {'id': 'dor_Mjj4yLIK', 'text': 'DEKKER'},
#         {'id': 'active_task_Mjj4FJQL', 'text': 'Planning'},
#         {'id': 'comment_Mjj4ErAr',
#          'text': 'Reduce sq ft reduction by 30,000.  Pending updated cost estimate to verify within budget.  Programming phase pending additional costs due to scope \n\n30%'},
#         {'id': 'contractor_Mjj47NUD', 'text': 'TBD'},
#         {'id': 'project_timeline', 'text': ''},
#         {'id': 'timerange_mkty93q3', 'text': ''},
#         {'id': 'formula_mktys6gm', 'text': ''},
#         {'id': 'project_duration', 'text': ''},
#         {'id': 'project_task_completion_date', 'text': ''},
#         {'id': 'date_mktynmfm', 'text': ''},
#         {'id': 'formula_mktyrxna', 'text': ''},
#         {'id': 'subitems_Mjj4Ab1e', 'text': None},
#         {'id': 'project_owner', 'text': ''},
#         {'id': 'project_status', 'text': None},
#         {'id': 'active_task_Mjj45kec', 'text': ''},
#         {'id': 'project_budget', 'text': ''}]}]}}]},
#  'extensions': {'request_id': 'a35d84c0-6772-9b7b-b47a-58015c2dad94'}}
